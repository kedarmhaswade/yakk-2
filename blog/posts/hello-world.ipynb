# %% [markdown]
# # Hello from Quarto + Jupyter
# This is a demo post rendered by Quarto. You can mix code, Markdown, and plots.

# %%
import sys
print("Hello, Artificial World!")
# Out:
# Hello, Artificial World!
