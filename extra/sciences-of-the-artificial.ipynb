# %% [markdown]
# # The Sciences of the Artificial
# ## By: Herbert A. Simon
# ### (The MIT Press 2019, DOI: 10.7551/mitpress/12107.001.0001)

# %% [markdown]
# Michael Nielsen's weblog pointed me toward this book, written by an ACM Turing Award winner (1975) and a Nobel Laureate in Economics (1978) (perhaps one of a kind), Herbert A. Simon.
#
# Understanding Artificial Intelligence takes time. I have been intrigued by Intelligence in general and Artificial Intelligence in particular. Not the least because it is in vogue right now (2020s). I won't say I have always been interested in it. I wanted to understand computer programming by working in the industry after graduate school, where I was first introduced to Artificial Neural Networks, and could have continued to work in a research lab. However, my turn in the industry made me stay there. During that time, I couldn't pay much attention to how AI had changed as a field. Now that I have some time off from the industry, I feel better to take a fresh look at the field.
#
# Simon's book was perhaps a good way to understand the perspectives of a pioneer.
#
# These are my notes. I decorate my reflections about a narrative with 'KM:'.

# %% [markdown]
# ## Introduction by John Laird
# John Laird provides an introduction to the third edition. He includes a brief biographical sketch of Herb Simon, mainly focusing on his academic career. Simon worked with excellent colleagues, Allen Newell (his student and then friend and colleague), and Cliff Shaw.
#
# Laird says that he was searching for answers to questions like:
# > What was artificial intelligence? How did it compare to natural intelligence in humans? Was it really a science? Was it (and other _artificial sciences_) intrinsically different from natural sciences?
#
# And found that this book provides many answers (I'd say perspectives).
#
# Simon's main premise is that _artificial had real semantic content_, and he explored its meaning.
#
# Simon chose a definition of AI:
# > He began with a dictionary definition: "**Produced by art rather than by  nature; not genuine or natural; affected; not about the essence of the matter**," choosing the first definition. He refined it \[the definition of AI\] and extended it
# > - to _systems designed by humans to attain goals, and to function_, and
# > - to entities that adapt to goals and their environment.
#
# This presupposes a definition of _intelligence_. To me, intelligence, as first [defined by John McCarthy and refined by Richard Sutton](http://incompleteideas.net/IncIdeas/DefinitionOfIntelligence.html), suffices:
# > **Intelligence is the *computational part of the ability to achieve goals*. A goal-achieving system is more usefully understood in terms of _outcomes_ than in terms of _mechanisms_**.
#
# **KM**: This definition of intelligence draws heavily from the computational theory of mind, which revolves around a central question: **Does the human mind compute?** (and answers it in the affirmative).
#
# Let's take these two definitions of Intelligence and Artificial Intelligence as the starting point.
#
# ### Simon's Contributions
#
# Laird writes:
# > He \[Simon\] recognized that computers could not only process numbers but also perform symbolic computation and thus perform the same types of reasoning underlying human thought.
#
# And
#
# > What attracted me to Simon and Newell's work was their strategy of developing artificial intelligence systems that closely modeled what we knew of human intelligence, and conversely expanded our knowledge of what was computationally possible for human reasoning. This methodology was their _secret weapon_, which they openly espoused, but it still provided them with unique and novel insights throughout their careers.
#
# > Human behavior data was always an important component of  their theories, possibly best illustrated by the voluminous protocols in _Human Problem Solving_. Their use of knowledge from other fields went beyond psychology, and Simon was unique in the expanse of disciplines he could draw from. But just as important as drawing from many fields was that their theories be computational, and implemented in running computer programs: "In the computer field, the moment of truth is a running program; all else is prophecy."
#
# Laird tells us about Simon and Newell's reception of the Turing Award:
#
# > \[Awarded for\] "Basic contributions to artificial intelligence, the psychology of human cognition, and list processing." **Newell and Simon demystified what it means to think, providing both theory and empirical evidence as to many of the computational processes underlying thought.**"
#
# **KM**: Simon's work clearly presupposes the CTM ([Computational Theory of Mind](https://plato.stanford.edu/entries/computational-mind/)--This resource, Stanford Encyclopedia of Philosophy, is valuable!)
#
# Simon, along with his excellent colleagues, made many contributions across large, independently recognized fields of study and research. I cite below some of those enumerated by Laird. As of 2016, according to Google Scholar, Simon is one of the most highly cited AI/Cognitive Psychology authors:
#
# 1) [Why a Diagram is (Sometimes) Worth Ten Thousand Words](https://github.com/kedarmhaswade/yakk-2/tree/main/ref-papers/larkin-simon-why-a-diagram-is-sometimes-worth-10k-words-cognitive-science-jan-mar-1987.pdf)
# 2) [A Theory of Learning by Doing](https://github.com/kedarmhaswade/yakk-2/tree/main/ref-papers/anzai-simon-theory-of-learning-psychologica-review-v86-n2-1979.pdf)
# 3) [Protocol Analysis](https://archive.org/details/protocolanalysis0000eric/page/n1/mode/2up): **Use of a psychologist's _subject_'s own verbal reports as data**
#
# **KM**: I wonder what Simon would say of ChatGPT, Gemini, and many other agentic AI systems of 2025! I hope he would feel vindicated ...
#
# Laird returned to this book after a long hiatus (The book has had three editions):
# > In returning to this book after many years, it is a pleasure to see once again how Simon distilled the essential ideas from **his lifelong pursuit of understanding organizations and the human mind**.
#
# > One of the joys of reading this book is that you do get to see foundational ideas from your own discipline reflected in others, giving deeper insight into them. Simon's strength as a writer is that a reader does not have to be well-versed in every field that he covers, nor
# have an advanced degree in any of those areas.
# > He provides building blocks to understand fields as diverse as AI, design, psychology, and economics. My background is in computer science, artificial intelligence, and, to a lesser extent, cognitive psychology. Still, I find all these topics accessible (and fascinating), including organizational administration, economics, biology, evolution, and design (KM: Might I add _Operations Research_?).
#
#
# Laird introduces 'Simon's Ant' (wherein Simon thinks of humans to be no more complex than ants):
# > I will not attempt to give a comprehensive overview of the book--Simon provides that in the first chapter: "Understanding the Natural and the Artificial Worlds"- but I will explore one of the most memorable aspects of the book, his parable of the ant on the beach, because of its simplicity, and also because of the continued relevance of the underlying ideas it embodies.
# > ...
# > Simon extends this \[the scenario of an ant walking a 'complex' terrain of a beach\] to human behavior, arguing that the basic structures underlying human behavior
# are actually quite simple--**we are just like the ant, pursuing our goals, attempting to find satisfactory solutions to our current problems, and that the complexity of our behavior is a reflection of the complexity of our tasks, our embodiment, and our environment**:
# > >"Human beings, viewed as behaving systems, are quite simple. **The apparent complexity of our behavior over time is largely a reflection of the complexity of the environment in which we find ourselves.**"
#
# **KM**: Such reductionism of complex human beings to simple ants (even though both are navigating a complex terrain) makes many of us uncomfortable (perhaps emotionally). **Are we merely huge goal-seeking ants?** I am still unsure, but it is undeniable that at least a significant part of our--' thinking' people's -- existence is about achieving goals of various kinds ...
#
# **KM**: In our case, we seem to be overly concerned about the finitude of 'our time' here. We even think of death as "a sad reality." Is an ant, which also has biological drives similar to us, aware of passing _Time_? We have no way of knowing its perception of Time. Many of us, however, are keenly aware of Time and want to do more before finally resting. This endeavor compels us to create and use sophisticated tools, optimize, and automate!
#
# **KM**: Is AI humanity's 'ultimate tool'? Perhaps. On the one hand, it feels like "advanced technology", and as such, it is indistinguishable from magic to its users. On the other hand, however, it may be the current culmination of tools we have been building (i.e., it is a snapshot of a progression).
#
# Laird sums up the effect this book had on him:
# > **One of my surprises in revisiting the book was the recognition that the recent successes in game-playing programs are completely consistent with Simon's point of view**. [AlphaZero](https://github.com/kedarmhaswade/yakk-2/tree/main/ref-papers/alphazero-chess-shogi-self-play-reinforcement-learning-arxiv-1712.01815v1.pdf) can learn to play either Go or chess at the world-championship level. **Its learning mechanisms extract models of a game by playing millions of times against itself (self-play)**. _It learns a symbolic model of the game states and their transitions, and a statistical model of the expected value of those states and transitions_.
#
# > Using the learned models, the program does a look-ahead search to evaluate alternative moves, picking the best one given its available computational resources. It does not attempt to find the optimal move, which for these games is almost always impossible, but instead it _satisfices_, picking the best move given its knowledge of its environment. The learning and search components are significant scientific advances, but the real complexity of the final program is in its model of the game. **More generally, recent advances in Machine Learning are tied to the development of conceptually simple learning mechanisms that exploit massive computational resources and data to build better and better models of their environments.**
# >
# > It was a real pleasure to return one more time to _The Sciences of the Artificial_. It is one of my all-time favorite books. **Even though the world  has changed in ways unimaginable over the last fifty years, this book  still has ideas and analyses that seem \[to be] fresh. I was surprised, after all these years, how much I learned from it and how much it inspired me to think about deep problems in AI, cognitive science, economics, and beyond.**

# %% [markdown]
# ## Preface to the III, II Editions
# \[The book was reissued by the MIT Press in 2016, but the third edition came out in 1996, about 15 years after the second edition in 1981.\]
#
# The book is primarily a sequence of essays or lectures that Simon delivered in the US.
#
# In the third edition, Simon addressed issues of _complexity_.
#
# In the second edition preface, he says
# > These essays then attempt to explain how a science of the artificial is possible and to illustrate its nature. I have taken as my main examples the fields of economics (chapter 2), the psychology of cognition (chapters 3 and 4), and planning and engineering design (chapters 5 and 6).

# %% [markdown]
# ## Chapter 1 Understanding the Natural and the Artificial Worlds
# >  A natural science is a body of knowledge about some class of things--objects or phenomena--in the world: about the characteristics and properties that they have; about how they behave and interact with each other.
#
# With the example of a memorable vignette ("_Wonder, en is gheen wonder_": A wonder, and yet, no wonder) that the Dutch physicist Simon Stevin constructed (to demonstrate the law of the inclined plane), Simon says:
# > This is the task of natural science: to show that the wonderful is not incomprehensible, to show how it can be comprehended--but not to destroy wonder.
#
# > The world we live in today is much more a man-made, or artificial, world than it is a natural world. Almost every element in our environment shows evidence of human artifice (KM: He does not use _art_ or endeavor, but _artifice_, which means trick, cleverness).
#
# > Moreover, for most of us-- **the white-collared ones** --the significant part of the environment consists mostly of strings of artifacts called 'symbols' that we receive through eyes and ears in the form of written and spoken language and that we pour out into the environment--as I am now doing--by mouth or hand. The laws that govern these strings of symbols, the laws that govern the occasions on which we emit and receive them, and the determinants of their content are all consequences of our collective artifice.
#
# This is a plain but masterly commentary in the "defense of the _artificial_":
#
# > One may object that I exaggerate the artificiality of our world. Man must obey the law of gravity as surely as does a stone, and as a living organism, man must depend for food and in many other ways on the world of biological phenomena. **I shall plead guilty to overstatement, while protesting that the exaggeration is slight**. To say that an astronaut, or even an airplane pilot, is obeying the law of gravity, hence is a perfectly natural phenomenon, is true, but its truth calls for some sophistication in what we mean by 'obeying' a natural law. Aristotle did not think it _natural_ for heavy things to rise or light ones to fall (Physics, Book IV), but presumably, we have a deeper understanding of 'natural' than he did. So too, we must be careful about equating 'biological' with 'natural'.
#
# > A forest may be a phenomenon of nature, but a farm certainly is not. The very species upon which we depend for our food--our corn and our cattle--are artifacts of our ingenuity. **A plowed field is no more part of nature than an asphalted street--and no less**.
#
# He sets the stage for his book (or a collection of essays):
#
# > These examples set the terms of our problem, for **those things we call artifacts are not apart from nature**. They have no dispensation (KM: an exemption from some rule or obligation) to ignore or violate natural law. At the same time, they are adapted to human goals and purposes. They are what they are in order to satisfy our desire to fly or to eat well. As our aims change, so too do our artifacts, and vice versa.
#
# > If science is to encompass these objects and phenomena in which human purpose as well as natural law are embodied, it must have means for relating these two disparate components (KM: human purpose and the natural law). **The character of these means and their implications for certain areas of knowledge--economics, psychology, and design in particular--are the central concern of this book**.

# %% [markdown]
# ---
#
# **KM**: I had always wondered whether creations of nature's creations are _natural_. Is the silk that a silkworm produces more natural than a piece of silk or satin cloth produced by man? Is a grand problem (such as the journey of light from the Sun to Earth) posed somewhat silently by Nature _more natural_ than a problem in arithmetic posed by a man?
#
# I have realized that Nature is nonchalant, oblivious; she has no "purpose in mind." Nature's creations and apparent destructions are inescapable results of unassailable, often coercive, but aimless laws. However, natural laws governing worldly events have no inherent purpose.
#
# It feels to me that Simon is asking this question:
#
# A creation of some creation of Nature (e.g., a bird's nest, man's languages, houses, crops, rockets, drugs, computers, systems, and many other contraptions), on the other hand, is driven by a purpose. While achieving those purposes (or, as Simon phrases it, "satisfying those desires"), these creations of the second order must obey laws of Nature. Does that make such purpose-driven creations different from (or inferior to) creations of Nature inherently created without a specification, design, or purpose? And if so, are second-order creations worthy of immersive study at all?
#
# ---

# %% [markdown]
# ### The Artificial
# Simon carefully distinguishes among the meanings of natural, artificial, and _synthetic_.
# >  A gem made of glass colored to _resemble_ sapphire would be called artificial, while a man-made gem chemically indistinguishable from sapphire would be called synthetic. A similar distinction is often made between 'artificial' and 'synthetic' rubber.
#
# Sadly, Simon says, **our language seems to reflect man's deep distrust of his own products**.
#
# (**KM**: Isn't this because we don't trust \[profit-making] businesses? Simon hasn't yet discussed the place of 'business' in the bigger picture. Are businesses so untrustworthy? Why should legal, profit-making businesses be looked down upon? Is it related to man's apparently _grasping_ attitude and limits to growth?)

# %% [markdown]
# He then gives us a historical account of the term "artificial intelligence", although, surprisingly, he does not define 'intelligence' itself (yet)! Simon's is a first-hand experience; he attended an invited summer conference at Dartmouth in 1956, where "artificial intelligence" was coined.
# > I shall disclaim responsibility for this particular choice of terms. The phrase "artificial intelligence", which led me to it, was coined, I think, right on the Charles River, at MIT. Our own research groups at Rand and Carnegie Mellon University have preferred phrases like "complex information processing" and "simulation of cognitive processes." But then, we run into new terminological difficulties, for the dictionary also says that "to simulate" means "to assume or have the mere appearance or form of, without the reality; imitate; counterfeit; pretend."
#
# > **At any rate, "artificial intelligence" seems to be here to stay, and it may prove easier to cleanse the phrase than to dispense with it. In time, it will become sufficiently idiomatic that it will no longer be the target of cheap rhetoric**.
#
# The following is written lucidly. I paraphrase Simon:
#
# > **As soon as we introduce "synthesis" as well as "artifice," we enter the realm of engineering, for "synthetic" is often used in the broader sense of "designed" or "composed."**
#
# > **We speak of engineering as concerned with "synthesis," while science is concerned with "analysis."**
#
# > Synthetic, or artificial objects--and more specifically prospective artificial objects having desired properties--are the central objective of engineering activity and skill.
#
# > **_The engineer, and more generally the designer, is concerned with how things ought to be--how they ought to be in order to attain goals,
# and to function_**.
#
# > Hence, a science of the artificial will be closely akin to a science of engineering--but very different, as we shall see in my fifth chapter, from what goes currently by the name of "engineering science."
#
# ---
#
# (**KM**: Somehow, "Evolution of Species" occurred to me as I read this. I recalled Francisco Ayala's essay, "Darwin's Greatest Discovery: Design Without Designer". That distinction--In Nature, creations occur without an explicit design, and whenever creations originate from explicit designs, we call them artificial--makes more and more sense.)
#
# ---
#
# Simon also distinguishes between the descriptive ("What is") and the normative ("What Ought to be"). He identifies four indicia (KM: distinguishing marks) of the Artificial:
# -
